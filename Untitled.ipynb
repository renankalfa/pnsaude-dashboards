# %% [markdown]
# ## Import Data and Libraries

# %%
import pandas as pd

data = pd.read_csv('Fiocruz/PNS_2019.csv', sep=';', low_memory=False)

# %%
data.reset_index(inplace=True)

# %%
data.shape
# Out:
# (293726, 1088)

# %%
data
# Out:
#          index  V0001    V0024    UPA_PNS  V0006_PNS  V0015  V0020  V0022  \
# 0            0     11  1110011  110000016          1      1   2019    6.0
# 1            1     11  1110011  110000016          1      1   2019    6.0
# 2            2     11  1110011  110000016          1      1   2019    6.0
# 3            3     11  1110011  110000016          1      1   2019    6.0
# 4            4     11  1110011  110000016          1      1   2019    6.0
# ...        ...    ...      ...        ...        ...    ...    ...    ...
# 293721  293721     53  5310220  530044434         14      1   2019    4.0
# 293722  293722     53  5310220  530044434         14      1   2019    4.0
# 293723  293723     53  5310220  530044434         14      1   2019    4.0
# 293724  293724     53  5310220  530044434         14      1   2019    4.0
# 293725  293725     53  5310220  530044434         15      8   2019    NaN
#
#         V0026  V0031  ...  VDE002  VDE014   VDF002  VDF003  VDF004  VDL001  \
# ...

# %%
data.rename(columns={'index': 'id'}, inplace=True)
data
# Out:
#         id_pessoa  V0001    V0024    UPA_PNS  V0006_PNS  V0015  V0020  V0022  \
# 0               0     11  1110011  110000016          1      1   2019    6.0
# 1               1     11  1110011  110000016          1      1   2019    6.0
# 2               2     11  1110011  110000016          1      1   2019    6.0
# 3               3     11  1110011  110000016          1      1   2019    6.0
# 4               4     11  1110011  110000016          1      1   2019    6.0
# ...           ...    ...      ...        ...        ...    ...    ...    ...
# 293721     293721     53  5310220  530044434         14      1   2019    4.0
# 293722     293722     53  5310220  530044434         14      1   2019    4.0
# 293723     293723     53  5310220  530044434         14      1   2019    4.0
# 293724     293724     53  5310220  530044434         14      1   2019    4.0
# 293725     293725     53  5310220  530044434         15      8   2019    NaN
#
# ...

# %%
data.columns
# Out:
# Index(['id_pessoa', 'V0001', 'V0024', 'UPA_PNS', 'V0006_PNS', 'V0015', 'V0020',
#        'V0022', 'V0026', 'V0031',
#        ...
#        'VDE002', 'VDE014', 'VDF002', 'VDF003', 'VDF004', 'VDL001', 'VDM001',
#        'VDP001', 'VDR001', 'VDDATA'],
#       dtype='object', length=1088)

# %%
test = pd.read_excel('dicion__rio_de_vari__veis_pns_2019_21012022.xlsx')

# %%
test.head(5)
# Out:
#   Dicionário de variáveis - PNS 2019                   Unnamed: 1  Unnamed: 2  \
# 0                       Código da variável  Descrição da variável  Categorias
# 1                                      NaN                    NaN       Tipo
# 2       Parte 1 - Identificação e Controle                    NaN         NaN
# 3                                    V0001   Unidade da Federação          11
# 4                                      NaN                    NaN          12
#
#   Unnamed: 3
# 0        NaN
# 1  Descrição
# 2        NaN
# 3   Rondônia
# 4       Acre

# %% [markdown]
# ## Informações gerais

# %%
data[['V0001', ]]
# Out:
#         V0001
# 0          11
# 1          11
# 2          11
# 3          11
# 4          11
# ...       ...
# 293721     53
# 293722     53
# 293723     53
# 293724     53
# 293725     53
#
# [293726 rows x 1 columns]
