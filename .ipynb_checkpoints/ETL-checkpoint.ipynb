# %% [markdown]
# ## Import Data and Libraries

# %%
import pandas as pd

data = pd.read_csv('datasets/PNS_2019.csv', sep=';', low_memory=False)

# %%
data.reset_index(inplace=True)
data.rename(columns={'index': 'id'}, inplace=True)
data
# Out:
#             id      id  V0001    V0024    UPA_PNS  V0006_PNS  V0015  V0020  \
# 0            0       0     11  1110011  110000016          1      1   2019
# 1            1       1     11  1110011  110000016          1      1   2019
# 2            2       2     11  1110011  110000016          1      1   2019
# 3            3       3     11  1110011  110000016          1      1   2019
# 4            4       4     11  1110011  110000016          1      1   2019
# ...        ...     ...    ...      ...        ...        ...    ...    ...
# 293721  293721  293721     53  5310220  530044434         14      1   2019
# 293722  293722  293722     53  5310220  530044434         14      1   2019
# 293723  293723  293723     53  5310220  530044434         14      1   2019
# 293724  293724  293724     53  5310220  530044434         14      1   2019
# 293725  293725  293725     53  5310220  530044434         15      8   2019
#
# ...

# %%
data.columns
# Out:
# Index(['id', 'id', 'V0001', 'V0024', 'UPA_PNS', 'V0006_PNS', 'V0015', 'V0020',
#        'V0022', 'V0026',
#        ...
#        'VDE002', 'VDE014', 'VDF002', 'VDF003', 'VDF004', 'VDL001', 'VDM001',
#        'VDP001', 'VDR001', 'VDDATA'],
#       dtype='object', length=1089)

# %%
test = pd.read_excel('datasets/dicion__rio_de_vari__veis_pns_2019_21012022.xlsx')

# %%
test.head(5)

# %% [markdown]
# ## Informações gerais

# %%
data[['V0001', ]]
